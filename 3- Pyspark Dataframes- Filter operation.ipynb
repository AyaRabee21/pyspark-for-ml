# %% [markdown]
# ### Pyspark Dataframes
# #### Filter Operation
# #### &,|,==
# #### ~

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
df=spark.read.csv('dataset/test1.csv',header=True,inferSchema=True)
df.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# ### Filter Operations

# %%
### Salary of the people less than or equal to 20000
df.filter('Salary<=20000').select(['Name','age','Salary']).show()
# Out:
# +-------+---+------+
# |   Name|age|Salary|
# +-------+---+------+
# |  Sunny| 29| 20000|
# |   Paul| 24| 20000|
# | Harsha| 21| 15000|
# |Shubham| 23| 18000|
# +-------+---+------+

# %%
df.filter(~(df['Salary']<=20000)).show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# +---------+---+----------+------+

# %%
df.filter((df['Salary']<=20000) & (df['Experience']<8)).show()
# Out:
# +-------+---+----------+------+
# |   Name|age|Experience|Salary|
# +-------+---+----------+------+
# |  Sunny| 29|         4| 20000|
# |   Paul| 24|         3| 20000|
# | Harsha| 21|         1| 15000|
# |Shubham| 23|         2| 18000|
# +-------+---+----------+------+
